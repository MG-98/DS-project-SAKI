# %%
import urllib.request 
import json
import pandas as pd 
import psycopg2
import sqlite3

# %%
hotspots_in_koeln_data_url = ' https://geoportal.stadt-koeln.de/arcgis/rest/services/politik_und_verwaltung/breitbandinfrastrukturkataster/MapServer/13/query?where=objectid%20is%20not%20null&text=&objectIds=&time=&geometry=&geometryType=esriGeometryEnvelope&inSR=&spatialRel=esriSpatialRelIntersects&distance=&units=esriSRUnit_Foot&relationParam=&outFields=%2A&returnGeometry=true&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=4326&havingClause=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&historicMoment=&returnDistinctValues=false&resultOffset=&resultRecordCount=&returnExtentOnly=false&datumTransformation=&parameterValues=&rangeValues=&quantizationParameters=&featureEncoding=esriDefault&f=pjson'
road_sections_data_url = 'https://geoportal.stadt-koeln.de/arcgis/rest/services/basiskarten/kgg_labeled/MapServer/9/query?where=objectid%20is%20not%20null&text=&objectIds=&time=&geometry=&geometryType=esriGeometryEnvelope&inSR=&spatialRel=esriSpatialRelIntersects&distance=&units=esriSRUnit_Foot&relationParam=&outFields=%2A&returnGeometry=true&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=4326&havingClause=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&historicMoment=&returnDistinctValues=false&resultOffset=&resultRecordCount=&returnExtentOnly=false&datumTransformation=&parameterValues=&rangeValues=&quantizationParameters=&featureEncoding=esriDefault&f=pjson'

# %%
# data extraction 
def data_extractor_from_url(url):
    with urllib.request.urlopen(url) as url:
        data = json.load(url)
        #print(json.dumps(data, indent=4))
    return data

# %%
hotspots_in_koeln_data = data_extractor_from_url(hotspots_in_koeln_data_url)
road_sections_data = data_extractor_from_url(road_sections_data_url)

# %%
# data transformation
hotspots_in_koeln_DF = pd.json_normalize(hotspots_in_koeln_data['features']) 
hotspots_in_koeln_DF.rename(columns={'attributes.objectid': 'OBJECTID', 'attributes.stadtbezirk': 'Stadtbezirk' , 'attributes.ap_name':'AP Name' ,  'attributes.strassenname':'Straßenname' ,
 'attributes.haus_nr': 'Haus Nr' , 'attributes.auftragsstatus_gesamt' :'Auftragsstatus Gesamt' , 'geometry.x' :'Geometry_x' , 'geometry.y':'Geometry_y' }, inplace=True)

# %%
hotspots_in_koeln_DF
# Out:
#      OBJECTID Stadtbezirk               AP Name       Straßenname Haus Nr  \
# 0           1  Innenstadt    AP-Aachener-Str-01   Aachener Straße      12
# 1           2  Innenstadt    AP-Aachener-Str-02   Aachener Straße      38
# 2           3  Innenstadt    AP-Aachener-Str-03   Aachener Straße   60-62
# 3           4  Innenstadt    AP-Aachener-Str-04   Aachener Straße      76
# 4           5  Innenstadt    AP-Aachener-Str-05   Aachener Straße      88
# ..        ...         ...                   ...               ...     ...
# 195       196  Chorweiler  AP-Weserpromenade-02    Weserpromenade      14
# 196       197      Nippes    AP-Wilhelmplatz-01      Wilhelmplatz      1a
# 197       198  Innenstadt  AP-Zuelpicher-Str-01  Zülpicher Straße      2a
# 198       199  Innenstadt  AP-Zuelpicher-Str-02  Zülpicher Straße      18
# 199       200  Innenstadt  AP-Zuelpicher-Str-03  Zülpicher Straße      38
#
#     Auftragsstatus Gesamt  Geometry_x  Geometry_y
# 0              In Betrieb    6.937254   50.936539
# 1              In Betrieb    6.935648   50.936562
# 2              In Betrieb    6.933976   50.936620
# 3              In Betrieb    6.932288   50.936639
# 4              In Betrieb    6.930443   50.936672
# ..                    ...         ...         ...
# 195            In Betrieb    6.893046   51.028042
# 196            In Betrieb    6.952416   50.962953
# 197            In Betrieb    6.939067   50.930042
# 198            In Betrieb    6.938429   50.929832
# 199            In Betrieb    6.937075   50.929072
#
# [200 rows x 8 columns]

# %%
road_sections_DF = pd.json_normalize(road_sections_data['features']) 
road_sections_DF.rename(columns={'attributes.objectid': 'OBJECTID', 'attributes.nummer': 'Nummer' , 'attributes.strasse':'Straße' ,  'attributes.hsnr_von_links':'Hausnummer von links' ,
 'attributes.hsnr_bis_links': 'Hausnummer bis links' , 'attributes.hsnr_von_rechts' :'Hausnummer von rechts' ,'attributes.hsnr_bis_rechts' :'Hausnummer bis rechts' ,
  'attributes.laenge': 'Länge (m)' ,'attributes.globalid': 'GLOBALID' , 'attributes.st_length(shape)': 'st_length(shape)' , 'geometry.paths' :'Geometry_paths'  }, inplace=True)

# %%
road_sections_DF
# Out:
#       OBJECTID    Nummer                  Straße Hausnummer von links  \
# 0         8289  02274010              Mühlenbach                 0007
# 1           17  01475010      Hohenzollernbrücke                 0000
# 2           19  03206010   Fritz-Encke-Volkspark                 0000
# 3           21  03524010        Marienberger Hof                 0000
# 4           25  03758010         Trude-Herr-Park                 0000
# ...        ...       ...                     ...                  ...
# 9995      2368  00757020                Dornstr.                 0029
# 9996      2377  01614010             In der Lohn                 0001
# 9997      2378  02164010  Mathias-Faßbender-Str.                 0001
# 9998      2380  02443010        Ottokühlchensweg                 0001
# 9999      2386  01747030        Kasselberger Weg                 0151
#
#      Hausnummer bis links Hausnummer von rechts Hausnummer bis rechts  \
# 0                    0059                  0002                  0042
# 1                    0000                  0000                  0000
# 2                    0000                  0000                  0000
# 3                    0000                  0000                  0000
# 4                    0000                  0000                  0000
# ...                   ...                   ...                   ...
# 9995                 0039                  0012                  0028
# 9996                 0021                  0004                  0016
# 9997                 0011                  0002                  0002
# 9998                 0003                  0000                  0000
# 9999                 0169                  0100                  0110
#
#       Länge (m)                                GLOBALID  st_length(shape)  \
# 0         246.0  {3EB047DF-4233-4744-85CF-4B41E4658011}        246.129123
# 1         793.0  {5B623377-8801-4F4A-8091-EFF3FE545F88}        793.167401
# 2          16.0  {5BD40C55-E37E-4226-BCD4-7BA6C6B49797}         16.573388
# 3          18.0  {3F6C7D98-1CCE-4E94-BD2B-6F587C7D910F}         18.057309
# 4          23.0  {EBDA9939-444C-4C1A-9A4E-7898960C999B}         23.421432
# ...         ...                                     ...               ...
# 9995      137.0  {C3F72474-2D01-4D3B-A9C8-C58805CA2736}        137.950423
# 9996       97.0  {21A971B0-6AB2-47BE-8B50-259DEBFA8750}         97.854786
# 9997       48.0  {EDF192F7-20CF-4574-98C6-9F2899762065}         48.491095
# 9998      157.0  {CB84C3AF-EBFA-490C-8F6E-D615CE7C45FA}        157.433964
# 9999      566.0  {9AECFE71-10EB-4209-A282-D51C5D64EC81}        566.925048
#
#                                          Geometry_paths
# 0     [[[6.956258032574851, 50.93279687112151], [6.9...
# 1     [[[6.962856466278041, 50.94145686459681], [6.9...
# 2     [[[6.954365942979147, 50.89441413720378], [6.9...
# 3     [[[6.889100945432353, 51.00253044792337], [6.8...
# 4     [[[6.963864600538986, 50.924904035191844], [6....
# ...                                                 ...
# 9995  [[[6.858830739518484, 51.06936672564872], [6.8...
# 9996  [[[6.8686674347352525, 51.06394405320047], [6....
# 9997  [[[6.864395904782747, 51.06284923047446], [6.8...
# 9998  [[[6.858097499913728, 51.070335741846215], [6....
# 9999  [[[6.942738924178406, 51.03989424712196], [6.9...
#
# [10000 rows x 11 columns]

# %%
#establishing the connection
conn = psycopg2.connect(
   database="postgres", user='postgres', password='password', host='127.0.0.1', port= '5432'
)
conn.autocommit = True

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[9], line 2
#       1 #establishing the connection
# ----> 2 conn = psycopg2.connect(
#       3    database="postgres", user='postgres', password='password', host='127.0.0.1', port= '5432'
#       4 )
#       5 conn.autocommit = True
#       7 #Creating a cursor object using the cursor() method
#
# File ~/anaconda3/envs/QC/lib/python3.10/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "127.0.0.1", port 5432 failed: FATAL:  password authentication failed for user "postgres"
# connection to server at "127.0.0.1", port 5432 failed: FATAL:  password authentication failed for user "postgres"

# %%
#Preparing query to create a database
sql = '''CREATE database SAKI''';

#Creating a database
cursor.execute(sql)
print("Database created successfully........")

#Closing the connection
conn.close()
